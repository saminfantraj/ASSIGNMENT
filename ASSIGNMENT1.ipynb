# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://www.flipkart.com/mobile-phones-store?fm=neo%2Fmerchandising&iid=M_2d0fddd1-97ad-4627-b338-7e80e4ad3b65_1_372UD5BXDFYS_MC.ZRQ4DKH28K8J&otracker=hp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Mobiles_ZRQ4DKH28K8J&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L0_view-all&cid=ZRQ4DKH28K8J"

# %%
permission=requests.get(url)

# %%
permission
# Out:
# <Response [200]>

# %%
a_html=BeautifulSoup(permission.text)

# %%
a_html
# Out:
# <!DOCTYPE html>
# ...

# %%
product=a_html.select("._1W9f5C div")

# %%
product
# Out:
# [<div>1. POCO C31 (Royal Blue, 64 GB...</div>,
#  <div>2. POCO M4 Pro (Cool Blue, 128...</div>,
#  <div>3. realme C30 (Bamboo Green, 3...</div>,
#  <div>4. MOTOROLA g72 (Meteorite Gre...</div>,
#  <div>5. Nokia 105 SS</div>]

# %%
product_price=a_html.select(".UMT9wN")

# %%
product_price
# Out:
# [<div class="_30jeq3 UMT9wN">₹7,499</div>,
#  <div class="_30jeq3 UMT9wN">₹12,999</div>,
#  <div class="_30jeq3 UMT9wN">₹6,999</div>,
#  <div class="_30jeq3 UMT9wN">₹14,999</div>,
#  <div class="_30jeq3 UMT9wN">₹1,299</div>]

# %%
product_ratting=a_html.select("._3VDxyD")

# %%
product_ratting
# Out:
# [<div class="_3VDxyD"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div><span class="_34hpFu"><span>2,12,742 Ratings</span><span><span class="_2oY1qB">&amp;</span><span>13,426 Reviews</span></span></span></div>,
#  <div class="_3VDxyD"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div><span class="_34hpFu"><span>1,60,310 Ratings</span><span><span class="_2oY1qB">&amp;</span><span>14,165 Reviews</span></span></span></div>,
#  <div class="_3VDxyD"><div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div><span class="_34hpFu"><span>44,231 Ratings</span><span><span class="_2oY1qB">&amp;</span><span>2,770 Reviews</span></span></span></div>,
#  <div class="_3VDxyD"><div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div><span class="_34hpFu"><span>12,523 Ratings</span><span><span class="_2oY1qB">&amp;</span><span>1,648 Reviews</span></span></span></div>,
# ...

# %%
import pandas

# %%
product=pandas.DataFrame(product,columns=['product name'])

# %%
product
# Out:
#                         product name
# 0  1. POCO C31 (Royal Blue, 64 GB...
# 1  2. POCO M4 Pro (Cool Blue, 128...
# 2  3. realme C30 (Bamboo Green, 3...
# 3  4. MOTOROLA g72 (Meteorite Gre...
# 4                    5. Nokia 105 SS

# %%
product.to_csv("C:\\Users\\Admin\\Desktop\\balaji.csv")
